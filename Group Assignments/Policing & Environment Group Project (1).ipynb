# %%
import geopandas as gpd
import pandas as pd

# %%
ejsm = gpd.read_file('Data/EJSM_Scores/3add6368-e61a-4279-8cc3-ad1ccb0eaadf202041-1-180j648.ou0r.shp')

# %%
print(ejsm)
# Out:
#       OBJECTID     Tract_1  CIscore  HazScore  HealthScor  SVscore  CCVscore  \
# 0            1  6037920336       10         3           1        4         2
# 1            2  6037920044        4         1           1        1         1
# 2            3  6037573003       13         5           3        3         2
# 3            4  6037571704       13         3           2        4         4
# 4            5  6037570403       17         5           3        5         4
# ...        ...         ...      ...       ...         ...      ...       ...
# 2338      2339  6037430302        6         2           1        1         2
# 2339      2340  6037430723       10         1           2        2         5
# 2340      2341  6037431100       14         5           2        3         4
# 2341      2342  6037533603       19         4           5        5         5
# 2342      2343  6037534101       17         5           5        5         2
#
#         Shape__Are   Shape__Len  \
# ...

# %%
type(ejsm)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
ejsm.head()
# Out:
#    OBJECTID     Tract_1  CIscore  HazScore  HealthScor  SVscore  CCVscore  \
# 0         1  6037920336       10         3           1        4         2
# 1         2  6037920044        4         1           1        1         1
# 2         3  6037573003       13         5           3        3         2
# 3         4  6037571704       13         3           2        4         4
# 4         5  6037570403       17         5           3        5         4
#
#      Shape__Are   Shape__Len  \
# 0  2.438560e+06  8124.373091
# 1  1.470811e+06  5545.298452
# 2  6.528168e+05  3310.743793
# 3  6.994011e+05  4113.477175
# 4  8.317839e+05  3887.000394
#
#                                             geometry
# 0  POLYGON ((-118.52876 34.38192, -118.52667 34.3...
# 1  POLYGON ((-118.50839 34.44845, -118.50816 34.4...
# 2  POLYGON ((-118.19925 33.79704, -118.19923 33.7...
# 3  POLYGON ((-118.18494 33.85434, -118.18493 33.8...
# 4  POLYGON ((-118.20057 33.88136, -118.20055 33.8...

# %%
ejsm.tail()
# Out:
#       OBJECTID     Tract_1  CIscore  HazScore  HealthScor  SVscore  CCVscore  \
# 2338      2339  6037430302        6         2           1        1         2
# 2339      2340  6037430723       10         1           2        2         5
# 2340      2341  6037431100       14         5           2        3         4
# 2341      2342  6037533603       19         4           5        5         5
# 2342      2343  6037534101       17         5           5        5         2
#
#         Shape__Are   Shape__Len  \
# 2338  2.837403e+06  8660.625349
# 2339  7.104454e+05  4760.545888
# 2340  4.412789e+06  9705.187477
# 2341  1.183445e+06  5970.437370
# 2342  7.432376e+05  5343.149124
#
#                                                geometry
# 2338  POLYGON ((-117.99173 34.15652, -117.99079 34.1...
# 2339  POLYGON ((-118.04961 34.13169, -118.04954 34.1...
# 2340  POLYGON ((-117.99875 34.14593, -117.99873 34.1...
# 2341  POLYGON ((-118.18743 33.97441, -118.18802 33.9...
# ...

# %%
ejsm.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 2343 entries, 0 to 2342
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   OBJECTID    2343 non-null   int64
#  1   Tract_1     2343 non-null   int64
#  2   CIscore     2343 non-null   int64
#  3   HazScore    2343 non-null   int64
#  4   HealthScor  2343 non-null   int64
#  5   SVscore     2343 non-null   int64
#  6   CCVscore    2343 non-null   int64
#  7   Shape__Are  2343 non-null   float64
#  8   Shape__Len  2343 non-null   float64
#  9   geometry    2343 non-null   geometry
# dtypes: float64(2), geometry(1), int64(7)
# memory usage: 183.2 KB

# %%
ejsm.info(verbose=True, null_counts=True)
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 2343 entries, 0 to 2342
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   OBJECTID    2343 non-null   int64
#  1   Tract_1     2343 non-null   int64
#  2   CIscore     2343 non-null   int64
#  3   HazScore    2343 non-null   int64
#  4   HealthScor  2343 non-null   int64
#  5   SVscore     2343 non-null   int64
#  6   CCVscore    2343 non-null   int64
#  7   Shape__Are  2343 non-null   float64
#  8   Shape__Len  2343 non-null   float64
#  9   geometry    2343 non-null   geometry
# dtypes: float64(2), geometry(1), int64(7)
# memory usage: 183.2 KB

# %%
ejsm.Tract_1.head()
# Out:
# 0    6037920336
# 1    6037920044
# 2    6037573003
# 3    6037571704
# 4    6037570403
# Name: Tract_1, dtype: int64

# %%
ejsm = gpd.read_file(
    'Data/EJSM_Scores/3add6368-e61a-4279-8cc3-ad1ccb0eaadf202041-1-180j648.ou0r.shp',
    dtype=
    {
        'Tract_1':str,
    }
)

# %%
ejsm['Tract_1']=ejsm['Tract_1'].apply(lambda x: '{0:0>10}'.format(x))
print (ejsm)
# Out:
#       OBJECTID     Tract_1  CIscore  HazScore  HealthScor  SVscore  CCVscore  \
# 0            1  6037920336       10         3           1        4         2
# 1            2  6037920044        4         1           1        1         1
# 2            3  6037573003       13         5           3        3         2
# 3            4  6037571704       13         3           2        4         4
# 4            5  6037570403       17         5           3        5         4
# ...        ...         ...      ...       ...         ...      ...       ...
# 2338      2339  6037430302        6         2           1        1         2
# 2339      2340  6037430723       10         1           2        2         5
# 2340      2341  6037431100       14         5           2        3         4
# 2341      2342  6037533603       19         4           5        5         5
# 2342      2343  6037534101       17         5           5        5         2
#
#         Shape__Are   Shape__Len  \
# ...

# %%
ejsm.head()
# Out:
#    OBJECTID     Tract_1  CIscore  HazScore  HealthScor  SVscore  CCVscore  \
# 0         1  6037920336       10         3           1        4         2
# 1         2  6037920044        4         1           1        1         1
# 2         3  6037573003       13         5           3        3         2
# 3         4  6037571704       13         3           2        4         4
# 4         5  6037570403       17         5           3        5         4
#
#      Shape__Are   Shape__Len  \
# 0  2.438560e+06  8124.373091
# 1  1.470811e+06  5545.298452
# 2  6.528168e+05  3310.743793
# 3  6.994011e+05  4113.477175
# 4  8.317839e+05  3887.000394
#
#                                             geometry
# 0  POLYGON ((-118.52876 34.38192, -118.52667 34.3...
# 1  POLYGON ((-118.50839 34.44845, -118.50816 34.4...
# 2  POLYGON ((-118.19925 33.79704, -118.19923 33.7...
# 3  POLYGON ((-118.18494 33.85434, -118.18493 33.8...
# 4  POLYGON ((-118.20057 33.88136, -118.20055 33.8...

# %%
tracts = gpd.read_file('Data/CensusData2012/census tract (2012).shp')

# %%
tracts.info
# Out:
# <bound method DataFrame.info of                                slug                   set  \
# 0     06037101110-census-tract-2012  Census Tracts (2012)
# 1     06037101122-census-tract-2012  Census Tracts (2012)
# 2     06037101210-census-tract-2012  Census Tracts (2012)
# 3     06037101220-census-tract-2012  Census Tracts (2012)
# 4     06037101300-census-tract-2012  Census Tracts (2012)
# ...                             ...                   ...
# 2341  06037980031-census-tract-2012  Census Tracts (2012)
# 2342  06037980033-census-tract-2012  Census Tracts (2012)
# 2343  06037990100-census-tract-2012  Census Tracts (2012)
# 2344  06037990200-census-tract-2012  Census Tracts (2012)
# 2345  06037990300-census-tract-2012  Census Tracts (2012)
#
#                      kind   external_i     name  \
# 0     Census Tract (2012)  06037101110  1011.10
# 1     Census Tract (2012)  06037101122  1011.22
# 2     Census Tract (2012)  06037101210  1012.10
# ...
